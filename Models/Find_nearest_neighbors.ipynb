# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import generate_tables_version2 as gt
# Out:
# /Users/shiahlints/anaconda3/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def find_nearest_neighbor_by_artist_genre(artist, bio = True):
    cv = CountVectorizer(stop_words='english', max_features=100)
    artist_with_genres = artists[~artists.genre.isnull()]
    artist_with_genres.iloc[[0]]
    genre_vectors = cv.fit_transform(artist_with_genres.genre)
    c = cv.transform(['latin'])
    c_neighbors = cosine_similarity(genre_vectors, c, dense_output=True)
    a = list((np.argsort(-c_neighbors, axis = 0)[0:10]).reshape(1,-1)[0])

# %%
events_raw = pd.read_csv('junk.csv')

# %%
venues = gt.make_venue_df(events_raw)

# %%
a = set([1,2,3])

# %%
a = [1,2,3,4]
b = a.copy()
b[0] = 78

# %%
dct =
# Out:
# [78, 2, 3, 4]

# %%
event_raw.genre
# Out:
# 0               Folk, Folk Revival, Americana, Songwriter
# 1               Folk, Folk Revival, Americana, Songwriter
# 2       Americana, Country, Red Dirt Country, Red Dirt...
# 3       Americana, Country, Red Dirt Country, Red Dirt...
# 4       Rock, Heavy Metal, Country Rock, Bobaflex, Har...
# 5       Rock, Heavy Metal, Country Rock, Bobaflex, Har...
# 6       Rock, Heavy Metal, Country Rock, Bobaflex, Har...
# 7                                              Funk, Jazz
# 8                                              Funk, Jazz
# 9                                              Funk, Jazz
# 10                                             Funk, Jazz
# 11                                             Funk, Jazz
# 12                                             Funk, Jazz
# 13                                             Funk, Jazz
# 14                                      Rock, Alternative
# 15      Rock N Roll, Sometimes Louder Than Others, Roc...
# 16      Rock N Roll, Sometimes Louder Than Others, Roc...
# 17      Rock N Roll, Sometimes Louder Than Others, Roc...
# 18      Rock N Roll, Sometimes Louder Than Others, Roc...
# 19      Rock N Roll, Sometimes Louder Than Others, Roc...
# 20      Rock N Roll, Sometimes Louder Than Others, Roc...
# 21           Reggae, Roots, Dub, Original Mountain Reggae
# 22           Reggae, Roots, Dub, Original Mountain Reggae
# 23           Reggae, Roots, Dub, Original Mountain Reggae
# 24           Reggae, Roots, Dub, Original Mountain Reggae
# 25           Reggae, Roots, Dub, Original Mountain Reggae
# 26      Worship, Christian Electronic, Christian Alter...
# 27      Worship, Christian Electronic, Christian Alter...
# 28      Worship, Christian Electronic, Christian Alter...
# 29      Worship, Christian Electronic, Christian Alter...
#                               ...
# 1644                                                 Punk
# 1645                                                 Punk
# 1646                                                 Punk
# 1647                                                 Punk
# 1648                                                 Punk
# 1649                                                 Punk
# 1650                                                 Punk
# 1651                     Relentless!, Punk Hardcore, Punk
# 1652                     Relentless!, Punk Hardcore, Punk
# 1653                     Relentless!, Punk Hardcore, Punk
# 1654                     Relentless!, Punk Hardcore, Punk
# 1655                                    Punk Thrash Metal
# 1656                                                  NaN
# 1657                                                  NaN
# 1658                                                  NaN
# 1659                          Country, Rock, Country Rock
# 1660                          Country, Rock, Country Rock
# 1661                          Country, Rock, Country Rock
# 1662                          Country, Rock, Country Rock
# 1663                          Country, Rock, Country Rock
# 1664                          Country, Rock, Country Rock
# 1665                                            Hard Rock
# 1666                                              Country
# 1667                                              Country
# 1668                                              Country
# 1669                              Pop, Influenced By Funk
# 1670                              Pop, Influenced By Funk
# 1671                              Pop, Influenced By Funk
# 1672                              Pop, Influenced By Funk
# 1673                              Pop, Influenced By Funk
# Name: genre, Length: 1674, dtype: object

# %%
event_raw['tour'] = event_raw.tour.apply(lambda x: ast.literal_eval(x))
# Out:
# /Users/shiahlints/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
event_data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30114 entries, 12 to 103363
# Data columns (total 30 columns):
# Unnamed: 0              30114 non-null int64
# _id                     30114 non-null object
# artist_facebook         17524 non-null object
# artist_image            30114 non-null object
# artist_name             30114 non-null object
# artist_thumb            30114 non-null object
# artist_url              30114 non-null object
# artists_id              30114 non-null int64
# bio                     20763 non-null object
# genre                   22917 non-null object
# home_town               17431 non-null object
# mbid                    9557 non-null object
# tracker_count           30114 non-null int64
# upcoming_event_count    30114 non-null int64
# offers                  30114 non-null object
# datetime                30114 non-null datetime64[ns]
# on_sale_datetime        30114 non-null object
# description             30114 non-null object
# lineup                  30114 non-null object
# event_id                30114 non-null int64
# event_url               30114 non-null object
# band_name               30114 non-null object
# venue_name              30114 non-null object
# country                 30114 non-null object
# region                  30114 non-null object
# city                    30114 non-null object
# latitude                30002 non-null float64
# longitude               30002 non-null float64
# vn_original             30114 non-null object
# venueidentifer          30114 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(22)
# memory usage: 8.4+ MB

# %%
event1 = splitDataFrameList(event_raw,'tour')

# %%
event_df = event_data_raw.copy()

# %%
event_df['venueidentifer'] = event_df['venue_name'] +' '+event_df['city']\
                                +' '+event_df['region']+' '+event_df['country']

# %%
event_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30114 entries, 12 to 103363
# Data columns (total 30 columns):
# Unnamed: 0              30114 non-null int64
# _id                     30114 non-null object
# artist_facebook         17524 non-null object
# artist_image            30114 non-null object
# artist_name             30114 non-null object
# artist_thumb            30114 non-null object
# artist_url              30114 non-null object
# artists_id              30114 non-null int64
# bio                     20763 non-null object
# genre                   22917 non-null object
# home_town               17431 non-null object
# mbid                    9557 non-null object
# tracker_count           30114 non-null int64
# upcoming_event_count    30114 non-null int64
# offers                  30114 non-null object
# datetime                30114 non-null datetime64[ns]
# on_sale_datetime        30114 non-null object
# description             30114 non-null object
# lineup                  30114 non-null object
# event_id                30114 non-null int64
# event_url               30114 non-null object
# band_name               30114 non-null object
# venue_name              30114 non-null object
# country                 30114 non-null object
# region                  30114 non-null object
# city                    30114 non-null object
# latitude                30002 non-null float64
# longitude               30002 non-null float64
# vn_original             30114 non-null object
# venueidentifer          30114 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(22)
# memory usage: 7.1+ MB

# %%
event_df[['venue_name', 'vn_original']]
# Out:
#                                  venue_name  \
# 12                 pig out in park festival
# 13                tumbleweed music festival
# 30                                     test
# 31                                     test
# 40      gas too broke to rock feat bobaflex
# 41                                     test
# 42                                     test
# 57                            nectar lounge
# 59                                     test
# 60                                     test
# 61                  yoshis oakland 8pm show
# 62                                     test
# 63                  yoshis oakland 8pm show
# 64                                     test
# 85                                     test
# 91                              brewminatti
# 92                               hotel utah
# 93                           secret society
# 94                         music millennium
# 95                           firefly lounge
# 96                          hotel albatross
# 104                                    test
# 105             roseway organics dispensary
# 106                               high dive
# 107                          airport tavern
# 108                              big dipper
# 113                       hope is here tour
# 114                       hope is here tour
# 115                       hope is here tour
# 116                       hope is here tour
# ...                                     ...
# 101835                                 test
# 101836                       staples center
# 101925            justin lee at old crow hb
# 101926        justin lee at old crow orange
# 102071            avila beach yoga festival
# 102073                        mayfair hotel
# 102091                   lake tahoe aleworx
# 102092                   lake tahoe aleworx
# 102293                                 test
# 102294                       staples center
# 102328               fivepoint amphitheater
# 102372                                 test
# 102374              trails vistas art hikes
# 102393   sammy hagars high tide beach party
# 102409            lindsay community theatre
# 102478                       valhalla tahoe
# 102793                 whiskey dicks saloon
# 102848               huntington state beach
# 102984                                 test
# 103097      valhalla art and music festival
# 103099                       chain reaction
# 103110                                siren
# 103132                               moodys
# 103133                               moodys
# 103134                               moodys
# 103135                  barrelhouse brewing
# 103242                                 test
# 103276                     crazy world tour
# 103283                        sycuan casino
# 103363            humphreys concerts by bay
#
#                                           vn_original
# 12                       Pig Out in the Park Festival
# 13                          Tumbleweed Music Festival
# 30                              Pendleton Roundup PBR
# 31                              Pendleton Roundup PBR
# 40              Ga's Too Broke To Rock Feat. Bobaflex
# 41                              Analog Cafe & Theater
# 42                              Seattle Hempfest 2018
# 57                                      Nectar Lounge
# 59                     Kuumbwa Jazz Center (7PM show)
# 60                     Kuumbwa Jazz Center (9PM show)
# 61                         Yoshi's Oakland (8PM show)
# 62                        Yoshi's Oakland (10PM show)
# 63                         Yoshi's Oakland (8PM show)
# 64                        Yoshi's Oakland (10PM show)
# 85      GA’s Too broke to rock #44 w/ Bobaflex & JIBE
# 91                                      Brewminatti +
# 92                                       Hotel Utah +
# 93                              The Secret Society ++
# 94                                Music Millennium ++
# 95                               The Firefly Lounge +
# 96                                  Hotel Albatross +
# 104                              The Spot Bar & Grill
# 105                       Roseway Organics Dispensary
# 106                                         High Dive
# 107                                    Airport Tavern
# 108                                    The Big Dipper
# 113                                 Hope Is Here Tour
# 114                                 Hope Is Here Tour
# 115                                 Hope Is Here Tour
# 116                                 Hope Is Here Tour
# ...                                               ...
# 101835                         SAP Center At San Jose
# 101836                                 Staples Center
# 101925                      Justin Lee at Old Crow HB
# 101926                  Justin Lee at Old Crow Orange
# 102071                      Avila Beach Yoga Festival
# 102073                              The Mayfair Hotel
# 102091                             Lake Tahoe Aleworx
# 102092                             Lake Tahoe Aleworx
# 102293                         SAP Center At San Jose
# 102294                                 Staples Center
# 102328                         FivePoint Amphitheater
# 102372                                     MSC Venue
# 102374                      Trails & Vistas Art Hikes
# 102393            Sammy Hagar's High Tide Beach Party
# 102409                      Lindsay Community Theatre
# 102478                                 Valhalla Tahoe
# 102793                          Whiskey Dick's Saloon
# 102848                         Huntington State Beach
# 102984                 Pattern Bar - Temple Tuesday’s
# 103097               Valhalla Art and Music Festival
# 103099                                 Chain Reaction
# 103110                                      The Siren
# 103132                                        Moody's
# 103133                                       Moody's
# 103134                                       Moody's
# 103135                            Barrelhouse Brewing
# 103242              Dia De Los Deftones at Petco Park
# 103276                               Crazy World Tour
# 103283                                  Sycuan Casino
# 103363                  Humphreys Concerts By the Bay
#
# [30114 rows x 2 columns]

# %%
df4 = df3.venue.apply(pd.Series)

# %%
df4
# Out:
#                                                      name        country  \
# 0                                         Forester's Club  United States
# 1                                           House Concert  United States
# 2                                      Norris Hot Springs  United States
# 3                                      Blackbird Espresso  United States
# 4                                                Icehouse  United States
# 5                                         Driftless Books  United States
# 6                                           House Concert  United States
# 7                               Great River Folk Festival  United States
# 8                                              Murray Bar  United States
# 9                                       The Celtic Cowboy  United States
# 10                       Columbia Falls Community Market   United States
# 11                  The Sitting Duck - Music on the Patio  United States
# 12                           Pig Out in the Park Festival  United States
# 13                              Tumbleweed Music Festival  United States
# 14          Dirty River Boys w/ Tylor & the Train Robbers  United States
# 15                                Velvet Falls Dance Hall  United States
# 16                                          Tom Grainey's  United States
# 17                                  Mohoney's Bar & Grill  United States
# 18                                          Marilyn's Bar  United States
# 19                                     Eureka Opera House  United States
# 20                                    Indian Creek Plaza   United States
# 21                                          Tom Grainey's  United States
# 22           Tylor & the Train Robbers w/ Timmy the Teeth  United States
# 23      Tylor & the Train Robbers w/ Kyle Allgood & th...  United States
# 24      Tylor & the Train Robbers w/ Kyle Allgood & th...  United States
# 25                                          Private Event  United States
# 26                         Bellevue Labor Day Celebration  United States
# 27                                          Tom Grainey's  United States
# 28                                         Garage on Beck  United States
# 29                                          Private Event  United States
# ...                                                   ...            ...
# 103401       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103402       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103403       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103404       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103405       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103406       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103407       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103408       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103409       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103410       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103411       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103412       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103413       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103414       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103415       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103416       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103417       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103418       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103419       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103420       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103421       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103422       Donny & Marie Showroom at Flamingo Las Vegas  United States
# 103423                           Mystic Lake Casino Hotel  United States
# 103424  Silver Creek Event Center at Four Winds New Bu...  United States
# 103425                 Hard Rock Rocksino Northfield Park  United States
# 103426                        Turning Stone Resort Casino  United States
# 103427         Event Center At Borgata Hotel Casino & Spa  United States
# 103428                                  Chevalier Theater  United States
# 103429                       Sands Bethlehem Event Center  United States
# 103430                        Mayo Performing Arts Center  United States
#
#        region            city           latitude           longitude
# 0          ID          Mccall          44.906183        -116.1171311
# 1          ID      Sun Valley         43.6971294        -114.3517172
# 2          MT          Norris         45.5704366        -111.6904522
# 3          SD       Spearfish         44.4908172        -103.8593697
# 4          MN     Minneapolis          44.977753         -93.2650108
# 5          WI         Viroqua         43.5569174  -90.88874129999999
# 6          WI          Beloit         42.5083482  -89.03177649999999
# 7          WI       La Crosse  43.81377510000001  -91.25190169999999
# 8          MT      Livingston         45.6614105        -110.5599556
# 9          MT     Great Falls         47.5039363        -111.3050162
# 10         MT       Kalispell           48.37104         -114.182901
# 11         MT         Bigfork         47.9981859        -114.0464208
# 12         WA       Riverside         47.6601247        -117.4160607
# 13         WA        Richland  46.28042000000001        -119.2751996
# 14         ID         Stanley  44.21553919999999        -114.9351998
# 15         ID         Stanley  44.21553919999999        -114.9351998
# 16         ID           Boise         43.6150186        -116.2023137
# 17         ID        Bellevue         43.4635179        -114.2605999
# 18         ID      Twin Falls         42.5558381        -114.4700518
# 19         NV          Eureka         39.5127778        -115.9597222
# 20         ID        Caldwell  43.66293839999999        -116.6873596
# 21         ID           Boise         43.6150186        -116.2023137
# 22         UT           Provo         40.2338438        -111.6585337
# 23         CO           Craig         40.5152491        -107.5464541
# 24         CO           Craig         40.5152491        -107.5464541
# 25         ID          Ashton         44.0715807        -111.4482884
# 26         ID        Bellevue         43.4635179        -114.2605999
# 27         ID           Boise         43.6150186        -116.2023137
# 28         UT  Salt Lake City         40.7607793        -111.8910474
# 29         UT  Salt Lake City         40.7607793        -111.8910474
# ...       ...             ...                ...                 ...
# 103401     NV       Las Vegas          36.115675        -115.1725564
# 103402     NV       Las Vegas          36.115675        -115.1725564
# 103403     NV       Las Vegas          36.115675        -115.1725564
# 103404     NV       Las Vegas          36.115675        -115.1725564
# 103405     NV       Las Vegas          36.115675        -115.1725564
# 103406     NV       Las Vegas          36.115675        -115.1725564
# 103407     NV       Las Vegas          36.115675        -115.1725564
# 103408     NV       Las Vegas          36.115675        -115.1725564
# 103409     NV       Las Vegas          36.115675        -115.1725564
# 103410     NV       Las Vegas          36.115675        -115.1725564
# 103411     NV       Las Vegas          36.115675        -115.1725564
# 103412     NV       Las Vegas          36.115675        -115.1725564
# 103413     NV       Las Vegas          36.115675        -115.1725564
# 103414     NV       Las Vegas          36.115675        -115.1725564
# 103415     NV       Las Vegas          36.115675        -115.1725564
# 103416     NV       Las Vegas          36.115675        -115.1725564
# 103417     NV       Las Vegas          36.115675        -115.1725564
# 103418     NV       Las Vegas          36.115675        -115.1725564
# 103419     NV       Las Vegas          36.115675        -115.1725564
# 103420     NV       Las Vegas          36.115675        -115.1725564
# 103421     NV       Las Vegas          36.115675        -115.1725564
# 103422     NV       Las Vegas          36.115675        -115.1725564
# 103423     MN      Prior Lake          44.730845          -93.473571
# 103424     MI     New Buffalo         41.7938889         -86.7438889
# 103425     OH      Northfield         41.3500299         -81.5266107
# 103426     NY          Verona          43.111606          -75.592926
# 103427     NJ   Atlantic City         39.3641667         -74.4233333
# 103428     MA         Medford         42.4196947         -71.1093959
# 103429     PA       Bethlehem          40.615424          -75.359412
# 103430     NJ      Morristown          40.785702          -74.499199
#
# [103431 rows x 6 columns]

# %%
def find_nearest_neighbor_by_artist_genre(artist, bio = True):
    cv = CountVectorizer(stop_words='english', max_features=100)
    artist_with_genres = artists[~artists.genre.isnull()]
    artist_with_genres.iloc[[0]]
    genre_vectors = cv.fit_transform(artist_with_genres.genre)
    c = cv.transform(['latin'])
    c_neighbors = cosine_similarity(genre_vectors, c, dense_output=True)
    a = list((np.argsort(-c_neighbors, axis = 0)[0:10]).reshape(1,-1)[0])

# %%
artist_with_genres.iloc[a]
# Out:
#       Unnamed: 0                       _id  \
# 5720        5720  5b77a7ce482deb635586620c
# 1139        1139  5b7741f4482deb63557faf87
# 8357        8357  5b784851482deb635586d88e
# 5096        5096  5b779988482deb6355851ad2
# 6256        6256  5b77b400482deb635586708f
# 4063        4063  5b778231482deb6355839b76
# 5078        5078  5b77990b482deb6355851a4a
# 6239        6239  5b77b38b482deb635586701b
# 8978        8978  5b78574f482deb635586e5b8
# 2719        2719  5b7764ed482deb63558377b7
#
#                                                     bio  \
# 5720  En el año 2003 nace un sueño de 16 músicos ent...
# 1139                                                NaN
# 8357                                                NaN
# 5096                                                NaN
# 6256                                                NaN
# 4063                                                NaN
# 5078                                                NaN
# 6239                                                NaN
# 8978          Acordeonista, compositor, 1era y 2da voz.
# 2719  FOLLOW ROMEO ON: www.romeosantosonline.com www...
#
#                                    artist_facebook                     genre  \
# 5720              https://www.facebook.com/BandaS7  Regional Mexicano, Latin
# 1139                                           NaN              Tango, Latin
# 8357                                           NaN                     Latin
# 5096                                           NaN                     Latin
# 6256                                           NaN                     Latin
# 4063                                           NaN                     Latin
# 5078                                           NaN              Latin, Salsa
# 6239                                           NaN              Latin, Salsa
# 8978        https://www.facebook.com/corneliovega/                     Latin
# 2719  https://www.facebook.com/RomeoSantosOfficial                     Latin
#
#            home_town  artists_id  \
# 5720  Santa Cruz, CA     3533915
# 1139             NaN      138478
# 8357             NaN     1366688
# 5096             NaN       97929
# 6256             NaN       57362
# 4063             NaN     1879362
# 5078             NaN        2990
# 6239             NaN       67324
# 8978  Ciudad Obregón    12988975
# 2719       Bronx, NY     1506749
#
#                                            artist_image  \
# 5720  https://s3.amazonaws.com/bit-photos/large/8381...
# 1139  https://s3.amazonaws.com/bit-photos/artistLarg...
# 8357  https://s3.amazonaws.com/bit-photos/large/8668...
# 5096  https://s3.amazonaws.com/bit-photos/large/1276...
# 6256  https://s3.amazonaws.com/bit-photos/artistLarg...
# 4063  https://s3.amazonaws.com/bit-photos/artistLarg...
# 5078  https://s3.amazonaws.com/bit-photos/artistLarg...
# 6239  https://s3.amazonaws.com/bit-photos/artistLarg...
# 8978  https://s3.amazonaws.com/bit-photos/large/8333...
# 2719  https://s3.amazonaws.com/bit-photos/large/7981...
#
#                                       mbid       artist_name  \
# 5720                                   NaN          BANDA S7
# 1139  985e1224-0784-452b-8cb2-caaf3d0698cc       3 Leg Torso
# 8357                                   NaN       Regulo Caro
# 5096  642b4142-bd0e-459e-a249-fd4a872f5217   Maria de Barros
# 6256  ce0646e2-98a4-4698-a494-c45034a03192   Pedro Fernández
# 4063                                   NaN         La Chamba
# 5078  d53d5b18-eb28-4b2d-a2e0-3fe2891a385f      Jerry Rivera
# 6239                                   NaN     andy montanez
# 8978                                   NaN  Cornelio Vega Jr
# 2719                                   NaN      Romeo Santos
#
#                                            artist_thumb  \
# 5720  https://s3.amazonaws.com/bit-photos/thumb/8381...
# 1139  https://s3.amazonaws.com/bit-photos/artistThum...
# 8357  https://s3.amazonaws.com/bit-photos/thumb/8668...
# 5096  https://s3.amazonaws.com/bit-photos/thumb/1276...
# 6256  https://s3.amazonaws.com/bit-photos/artistThum...
# 4063  https://s3.amazonaws.com/bit-photos/artistThum...
# 5078  https://s3.amazonaws.com/bit-photos/artistThum...
# 6239  https://s3.amazonaws.com/bit-photos/artistThum...
# 8978  https://s3.amazonaws.com/bit-photos/thumb/8333...
# 2719  https://s3.amazonaws.com/bit-photos/thumb/7981...
#
#                                                    tour  tracker_count  \
# 5720  [{'offers': [], 'venue': {'name': 'Privado-P',...            609
# 1139  [{'offers': [{'type': 'Tickets', 'url': 'https...           1440
# 8357  [{'offers': [{'type': 'Tickets', 'url': 'https...          42061
# 5096  [{'id': '1009624572', 'artist_id': '97929', 'u...           1078
# 6256  [{'id': '1010441603', 'artist_id': '57362', 'u...          27983
# 4063  [{'offers': [{'type': 'Tickets', 'url': 'https...            963
# 5078  [{'id': '1008790031', 'artist_id': '2990', 'ur...          24825
# 6239  [{'id': '1010740706', 'artist_id': '67324', 'u...           7106
# 8978  [{'offers': [], 'venue': {'name': 'Teatro Del ...           5296
# 2719  [{'id': '1010996908', 'artist_id': '1506749', ...         409236
#
#       upcoming_event_count                                         artist_url
# 5720                    27  https://www.bandsintown.com/a/3533915?came_fro...
# 1139                     2  https://www.bandsintown.com/a/138478?came_from...
# 8357                    19  https://www.bandsintown.com/a/1366688?came_fro...
# 5096                     1  https://www.bandsintown.com/a/97929?came_from=...
# 6256                     3  https://www.bandsintown.com/a/57362?came_from=...
# 4063                     9  https://www.bandsintown.com/a/1879362?came_fro...
# 5078                     4  https://www.bandsintown.com/a/2990?came_from=2...
# 6239                     4  https://www.bandsintown.com/a/67324?came_from=...
# 8978                    43  https://www.bandsintown.com/a/12988975?came_fr...
# 2719                    68  https://www.bandsintown.com/a/1506749?came_fro...
