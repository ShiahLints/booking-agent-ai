# %%
import model
import pandas as pd

# %%
a = model.recomend('Five Letter Word', 'WA', 'Seattle', 10, artist_genre1 = None)

# %%
artists = pd.read_pickle('../data/master_artists_df.p')

# %%
a = a[['venue_name','city','region']]
a.to_json(orient='index')
# Out:
# '{"7132":{"venue_name":"two pools house concert series","city":"Seattle","region":"WA"},"3737":{"venue_name":"lagunitas taproom seattle","city":"Seattle","region":"WA"},"6087":{"venue_name":"seattle folklore society","city":"Seattle","region":"WA"},"4685":{"venue_name":"north city bistro","city":"Shoreline","region":"WA"},"403":{"venue_name":"arundel books","city":"Seattle","region":"WA"},"2494":{"venue_name":"freemont abbey arts center","city":"Seattle","region":"WA"},"527":{"venue_name":"ballard homestead","city":"Seattle","region":"WA"},"950":{"venue_name":"briget boyle album release lonely coast and sheryl wiser","city":"Seattle","region":"WA"},"2032":{"venue_name":"edna vazquez pink martini","city":"Seattle","region":"WA"},"4868":{"venue_name":"one love flow w leah zaccaria","city":"Seattle","region":"WA"}}'

# %%
sorted(list(artists['artist_name'].values))
# Out:
# ['(hed)p.e.',
#  '(həd) p.e.',
#  '(thee) Mike B',
#  '*Jarvis Cocker*',
#  '*Lauryn Hill*',
#  '-The People-',
#  '08',
#  '1',
#  '10',
#  '10 String Symphony',
#  '10,000 Maniacs',
#  '100 Proof',
#  '11',
#  '112',
#  '12',
#  '12 Gauge Promise',
#  '12 Grand',
#  '12th Avenue Hot Club',
#  '12th Planet',
#  '13 Days',
#  '13th Chime',
#  '1476',
#  '16 Penny Band',
#  '1788-L',
#  '18 Wheels of Justice',
#  '1TON',
#  '2 8 Tha Native',
#  '2 Libras',
#  '2 Shadows',
#  '2 faced',
#  '2018',
#  '20SIX Hundred',
#  '21',
#  '222',
#  '24 Hour Bigfoot Attack',
#  '258',
#  '26',
#  '28',
#  '29 Palms',
#  '29TH STREET SWINGTET',
#  '2KLIX',
#  '3 Doors Down',
#  '3 Leg Torso',
#  '311',
#  '37',
#  '3LAU',
#  '3X Events and Artists',
#  '4',
#  '4 Lads From Liverpool',
#  '4B',
#  '5',
#  '5 Grand',
#  '5 Seconds Of Summer',
#  '54-40',
#  '68',
#  '6LACK',
#  '6ix9ine',
#  '7 Day Weekend',
#  '8',
#  '8 Track',
#  '8-Track',
#  '80 PROOF ALE',
#  '80s Night',
# ...
