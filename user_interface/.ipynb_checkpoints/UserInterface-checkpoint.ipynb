# %%
import sys
sys.path.insert(0, '/Users/shiahlints/galvanize/FIXGITPROBLEM/booking-agent-ai')
# %load_ext autoreload
# %autoreload 2
import pandas as pd

# %%
artists = pd.read_pickle('../data/master_artists_df.p')

# %%
artists = artists.rename({'bio':'artist_bio', 'genre':'artist_genre'}, axis = 'columns')
artists = artists[['artist_name', 'artist_bio', 'artist_genre']]

# %%
artist_names = artists.artist_name.values

# %%
def get_user_type():
    print ('Are you an Artist looking for a Venue')
    print ('A fan looking for a show to go to')
    print ('Or a Venue looking for a Performer')
    
    user_type = input('Please Artist, Fan, or Venue ')
    user_type = str.lower(user_type)
    while user_type not in ['artist', 'fan', 'venue']:    
        user_type = input('Improper input please try again ')
        user_type = str.lower(user_type)
    
    return user_type

# %%
def get_artist_name():
    
    answer = 'yes'
    while answer in ['yes', 'y']:
        artist_name = input('What is the name of your band?  ')
        if artist_name in artist_names:
            return artist_name
        else:
            answer = input('That name is not in our database would you like to search again?  ')
            answer = str.lower(answer)
    return None

# %%
def get_artist_genre():
    artist_genre = input('Please enter the genres of the band you play in.  ')
    return artist_genre
def get_artist_bio():
    artist_bio = input('Please wright a short paragraph about this artist.  ')
    return artist_bio

# %%
def user_interface():
    user_type = get_user_type()
    if user_type == 'artist':
        artist_name = get_artist_name()
        print (artist_name)
        if artist_name == None:
            artist_genre = get_artist_genre()
            artist_bio = get_artist_bio()
        else:
            artist = artists[artists.artist_name == artist_name]
            artist_bio = artist.artist_bio.values[0]
            artist_genre = artist.artist_genre.values[0]
            if artist_genre == None:
                answer = str.lower(input('It looks like this artist has no genre\n would you like to enter one?  '))
                if answer in ['yes', 'y']:
                    artsit_genre = input('Ok go for it  ')
            if artist_bio == None:
                answer = str.lower(input('It looks like this artist has no bio\n would you like to enter one?  '))
                if answer in ['yes', 'y']:
                    artsit_genre = input('Ok go for it  ')

# %%
user_interface()
# Out:
# Are you an Artist looking for a Venue
# A fan looking for a show to go to
# Or a Venue looking for a Performer
# Jetski

# %%
artist = artists[artists.artist_name == 'Jetski']

# %%
artist.artist_bio.values[0] == None
# Out:
# True

# %%
artists
# Out:
#                            artist_name  \
# 0                     Five Letter Word
# 1            Tylor & the Train Robbers
# 2                             Bobaflex
# 3                        Victor Wooten
# 4                                 Jibe
# 5                       Kasey Anderson
# 6                       Lindzey Autumn
# 7                          Policulture
# 8                           Mosaic MSC
# 9                        The Nightowls
# 10                             Winters
# 11                              Winter
# 12                       Chain Station
# 13                             Honyock
# 14                    The Sea, The Sea
# 15                    Shaun Peace Band
# 16                        Street Fever
# 17                The Sea The Sea (US)
# 18                              Jetski
# 19                      The Lucid Furs
# 20                      Brewer's Grade
# 21                   Steve Miller Band
# 22                      Peter Frampton
# 23                              De Lux
# 24                            Traps PS
# 25                     Transistor Send
# 26                        Napalm Death
# 27                             Anthrax
# 28                      Marshall Poole
# 29                              Slayer
# ...                                ...
# 9674                  Forming the Void
# 9675                 David Copperfield
# 9676                        Dell Feddi
# 9677                      Howie Mandel
# 9678                  The March Divide
# 9679                   The Peacemakers
# 9680                       Niall Horan
# 9681                       Magic Sword
# 9682                      Tito Jackson
# 9683                        DJ Chuckie
# 9684                           Mansion
# 9685                           MJ LIVE
# 9686                   Dustin Sheridan
# 9687                      All Shook Up
# 9688                Nikki McLeod Music
# 9689               Radio Free Honduras
# 9690                             Swine
# 9691                      Fresh Bakin'
# 9692                  Goodnight, Texas
# 9693                    David Krakauer
# 9694                    Dylan Jakobsen
# 9695                 ALL PIGS MUST DIE
# 9696  The Auto Collections at the Linq
# 9697             Rocket From the Crypt
# 9698                    Jarrett & Raja
# 9699                       Queensrÿche
# 9700                      Donny Osmond
# 9701                        Tiëstolive
# 9702                      The Monsters
# 9703                      Marie Osmond
#
#                                              artist_bio  \
# 0     A harmony-based folk trio made up of Leigh Jon...
# 1     Tylor & The Train Robbers debut album "Gravel"...
# 2     Originating in Mason, West Virginia, Bobaflex ...
# 3     “I like to talk and I like to play.”So said Vi...
# 4     "JIBE was poised to be one of if not the bigge...
# 5                            www.kaseyandersonmusic.com
# 6     21 years old | Located in Boise Idaho Guitaris...
# 7     Policulture is a five-piece band from Boulder,...
# 8     Introducing Mosaic MSC, the worship music that...
# 9     'Royal Sessions' really marks the beginning of...
# 10                                                 None
# 11    Winter is the project of songwriter Samira Win...
# 12    Chain Station is a 4-piece, high-energy, get '...
# 13                                                 None
# 14                                                 None
# 15    Mixing the roots of rock & roll, blues, & alte...
# 16                                                 None
# 17    THE SEA THE SEA is an Upstate New York based i...
# 18                                                 None
# 19    These bereaved souls are here to wash your min...
# 20    Original, contemporary, diverse and entertaini...
# 21    Steve Miller was a mainstay of the San Francis...
# 22    Grammy winner Peter Frampton remains one of th...
# 23    Booking North & South America - Jake@Circletal...
# 24                                                 None
# 25                                                 None
# 26    What makes NAPALM DEATH so special? Well, let’...
# 27    The hardest ever. Official Facebook of Anthrax...
# 28    Like weavers with a progressive loom, MP makes...
# 29    REPENTLESS IS A DECLARATION: THERE WILL BE NO ...
# ...                                                 ...
# 9674  "Progressive sludge metal that’s dynamic, enga...
# 9675                                               None
# 9676                                               None
# 9677  Howie Mandel has remained a constant force in ...
# 9678  The March Divide – Anticipation Pops – Slow St...
# 9679                                               None
# 9680                                               None
# 9681  Ages ago, the immortal Dark One was freed from...
# 9682  Tito Jackson (along with his brothers Jackie, ...
# 9683                                               None
# 9684                                               None
# 9685                                               None
# 9686  ♪♫♪♫♪♫♪♫♪ ( ( ( >>> d^_^b <<< ) ) ) ♪♫♪♫♪♫♪♫♪♫...
# 9687                                               None
# 9688  Some Kinda Reckless available now on all major...
# 9689  Radio Free Honduras is a mostly acoustic Latin...
# 9690         Los Angeles Hardcore Thrash Metal est 2013
# 9691  Bakin' up the freshest shows in Reno, Tahoe, a...
